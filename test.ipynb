# %%
import numpy as np
import os
import sys
import argparse

# %%
def load_asot_data(data_dir, args):
    filenames = []
    for filename in os.listdir(data_dir + '/pca_features'):
        true_name = filename.split('.')[0]
        filenames.append(true_name)


    data_files = []
    for filename in filenames:
        state_name = data_dir + f'/{args.feature_name}/' + filename + '.npy'
        action_name = data_dir + '/actions/' + filename + '.npy'
        ground_truth_name = data_dir + '/groundTruth/' + filename

        data_files.append((state_name, action_name, ground_truth_name))

    print(data_files)

    max_length = 0
    for file in data_files:
        #Load the npy file
        data = np.load(file[0])
        
        shape = data.shape #Length x feature_size 
        if shape[0] > max_length:
            max_length = shape[0]

    all_states = []
    all_actions = []
    all_ground_truth = []
    for file in data_files:
        state = np.load(file[0])
        action = np.load(file[1])
        with open(file[2], 'r') as file:
            ground_truth = file.read().splitlines()


        if state.shape[0] < max_length:
            state = np.pad(state, ((0, max_length - state.shape[0]), (0, 0)), mode='edge')
            action = np.pad(action, (0, max_length - action.shape[0]), mode='edge')
            ground_truth = np.pad(ground_truth, ((0, max_length - len(ground_truth))), mode='edge')


        all_states.append(state)
        all_actions.append(action)
        all_ground_truth.append(ground_truth)

    all_states = np.array(all_states).astype(np.float32)
    all_actions = np.array(all_actions).astype(np.int64)

    del data_files, filenames

    return all_states, all_actions, all_ground_truth

# %%
parser = argparse.ArgumentParser()


parser.add_argument('--feature-name', type=str, default='pca_features')

args = parser.parse_args()

load_asot_data('Data/wsws_random/wsws_random_pixels', args)
# Out:
# [('Data/wsws_random/wsws_random_pixels//run/user/1000/jupyter/runtime/kernel-v37e62834927b40d7d7b72815dd91a94e7292d049c.json/craftax_43.npy', 'Data/wsws_random/wsws_random_pixels/actions/craftax_43.npy', 'Data/wsws_random/wsws_random_pixels/groundTruth/craftax_43'), ('Data/wsws_random/wsws_random_pixels//run/user/1000/jupyter/runtime/kernel-v37e62834927b40d7d7b72815dd91a94e7292d049c.json/craftax_59.npy', 'Data/wsws_random/wsws_random_pixels/actions/craftax_59.npy', 'Data/wsws_random/wsws_random_pixels/groundTruth/craftax_59'), ('Data/wsws_random/wsws_random_pixels//run/user/1000/jupyter/runtime/kernel-v37e62834927b40d7d7b72815dd91a94e7292d049c.json/craftax_29.npy', 'Data/wsws_random/wsws_random_pixels/actions/craftax_29.npy', 'Data/wsws_random/wsws_random_pixels/groundTruth/craftax_29'), ('Data/wsws_random/wsws_random_pixels//run/user/1000/jupyter/runtime/kernel-v37e62834927b40d7d7b72815dd91a94e7292d049c.json/craftax_41.npy', 'Data/wsws_random/wsws_random_pixels/actions/craftax_41.npy', 'Data/wsws_random/wsws_random_pixels/groundTruth/craftax_41'), ('Data/wsws_random/wsws_random_pixels//run/user/1000/jupyter/runtime/kernel-v37e62834927b40d7d7b72815dd91a94e7292d049c.json/craftax_79.npy', 'Data/wsws_random/wsws_random_pixels/actions/craftax_79.npy', 'Data/wsws_random/wsws_random_pixels/groundTruth/craftax_79'), ('Data/wsws_random/wsws_random_pixels//run/user/1000/jupyter/runtime/kernel-v37e62834927b40d7d7b72815dd91a94e7292d049c.json/craftax_83.npy', 'Data/wsws_random/wsws_random_pixels/actions/craftax_83.npy', 'Data/wsws_random/wsws_random_pixels/groundTruth/craftax_83'), ('Data/wsws_random/wsws_random_pixels//run/user/1000/jupyter/runtime/kernel-v37e62834927b40d7d7b72815dd91a94e7292d049c.json/craftax_89.npy', 'Data/wsws_random/wsws_random_pixels/actions/craftax_89.npy', 'Data/wsws_random/wsws_random_pixels/groundTruth/craftax_89'), ('Data/wsws_random/wsws_random_pixels//run/user/1000/jupyter/runtime/kernel-v37e62834927b40d7d7b72815dd91a94e7292d049c.json/craftax_36.npy', 'Data/wsws_random/wsws_random_pixels/actions/craftax_36.npy', 'Data/wsws_random/wsws_random_pixels/groundTruth/craftax_36'), ('Data/wsws_random/wsws_random_pixels//run/user/1000/jupyter/runtime/kernel-v37e62834927b40d7d7b72815dd91a94e7292d049c.json/craftax_55.npy', 'Data/wsws_random/wsws_random_pixels/actions/craftax_55.npy', 'Data/wsws_random/wsws_random_pixels/groundTruth/craftax_55'), ('Data/wsws_random/wsws_random_pixels//run/user/1000/jupyter/runtime/kernel-v37e62834927b40d7d7b72815dd91a94e7292d049c.json/craftax_94.npy', 'Data/wsws_random/wsws_random_pixels/actions/craftax_94.npy', 'Data/wsws_random/wsws_random_pixels/groundTruth/craftax_94'), ('Data/wsws_random/wsws_random_pixels//run/user/1000/jupyter/runtime/kernel-v37e62834927b40d7d7b72815dd91a94e7292d049c.json/craftax_25.npy', 'Data/wsws_random/wsws_random_pixels/actions/craftax_25.npy', 'Data/wsws_random/wsws_random_pixels/groundTruth/craftax_25'), ('Data/wsws_random/wsws_random_pixels//run/user/1000/jupyter/runtime/kernel-v37e62834927b40d7d7b72815dd91a94e7292d049c.json/craftax_66.npy', 'Data/wsws_random/wsws_random_pixels/actions/craftax_66.npy', 'Data/wsws_random/wsws_random_pixels/groundTruth/craftax_66'), ('Data/wsws_random/wsws_random_pixels//run/user/1000/jupyter/runtime/kernel-v37e62834927b40d7d7b72815dd91a94e7292d049c.json/craftax_1.npy', 'Data/wsws_random/wsws_random_pixels/actions/craftax_1.npy', 'Data/wsws_random/wsws_random_pixels/groundTruth/craftax_1'), ('Data/wsws_random/wsws_random_pixels//run/user/1000/jupyter/runtime/kernel-v37e62834927b40d7d7b72815dd91a94e7292d049c.json/craftax_52.npy', 'Data/wsws_random/wsws_random_pixels/actions/craftax_52.npy', 'Data/wsws_random/wsws_random_pixels/groundTruth/craftax_52'), ('Data/wsws_random/wsws_random_pixels//run/user/1000/jupyter/runtime/kernel-v37e62834927b40d7d7b72815dd91a94e7292d049c.json/craftax_67.npy', 'Data/wsws_random/wsws_random_pixels/actions/craftax_67.npy', 'Data/wsws_random/wsws_random_pixels/groundTruth/craftax_67'), ('Data/wsws_ ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 8
#       4 parser.add_argument('--feature-name', type=str, default='pca_features')
#       6 args = parser.parse_args()
# ----> 8 load_asot_data('Data/wsws_random/wsws_random_pixels', args)
#
# Cell In[2], line 21, in load_asot_data(data_dir, args)
#      18 max_length = 0
#      19 for file in data_files:
#      20     #Load the npy file
# ---> 21     data = np.load(file[0])
#      23     shape = data.shape #Length x feature_size
#      24     if shape[0] > max_length:
#
# File ~/anaconda3/envs/compile/lib/python3.10/site-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data/wsws_random/wsws_random_pixels//run/user/1000/jupyter/runtime/kernel-v37e62834927b40d7d7b72815dd91a94e7292d049c.json/craftax_43.npy'
